# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('clean_smart_phone1.xlsx')

# %%
df['model_name'].unique()
# Out:
# array(['MOTOROLA g05', 'POCO C71', 'Samsung Galaxy F05',
#        'MOTOROLA Edge 60 Fusion', 'Motorola G85',
#        'vivo T4 Lite  Charger in the Box', 'MOTOROLA Edge 60', 'vivo T4R',
#        'Motorola g45', 'vivo T4x', 'Samsung Galaxy F06',
#        'Motorola Edge 50 Fusion', 'Tecno Spark Go 2', 'MOTOROLA G96',
#        'realme C61', 'vivo T4', 'Infinix SMART 9 HD', 'IQOO Z10X',
#        'CMF by Nothing Phone 2 Pro', 'Samsung Galaxy F16', 'POCO X7',
#        'OnePlus Nord CE5',
#        'OPPO K12x  with 45W SUPERVOOC Charger In-The-Box',
#        'Apple iPhone 14', 'Google Pixel 8a', 'POCO C61',
#        'Apple iPhone 15', 'Apple iPhone 15 Plus', 'Motorola g04s',
#        'POCO C51 - Locked with Airtel Prepaid', 'Motorola e40',
#        'realme C51', 'Motorola G34', 'Infinix Smart 7 HD', 'POCO M6 Pro',
#        'Apple iPhone 14 Plus', 'Motorola Edge 40 Neo', 'Ai+ Pulse',
#        'POCO C75', 'POCO M7', 'MOTOROLA g35', 'MOTOROLA G86 Power',
# ...

# %%
processor_map = {
    'MOTOROLA g05': 'Unisoc T606',
    'POCO C71': 'Unisoc T7250',
    'Samsung Galaxy F05': 'MediaTek Helio G85',
    'MOTOROLA Edge 60 Fusion': 'Qualcomm Snapdragon 7s Gen 2',
    'Motorola G85': 'Qualcomm Snapdragon 6s Gen 1',
    'vivo T4 Lite  Charger in the Box': 'MediaTek Helio G85',
    'MOTOROLA Edge 60': 'Qualcomm Snapdragon 7 Gen 1',
    'vivo T4R': 'MediaTek Helio G85',
    'Motorola g45': 'Unisoc T606',
    'vivo T4x': 'MediaTek Helio G88',
    'Samsung Galaxy F06': 'MediaTek Helio G85',
    'Motorola Edge 50 Fusion': 'Qualcomm Snapdragon 7 Gen 1',
    'Tecno Spark Go 2': 'MediaTek Helio A22',
    'MOTOROLA G96': 'Qualcomm Snapdragon 7s Gen 2',
    'realme C61': 'Unisoc T612',
    'vivo T4': 'MediaTek Helio G85',
    'Infinix SMART 9 HD': 'Unisoc T606',
    'IQOO Z10X': 'Qualcomm Snapdragon 6 Gen 1',
    'CMF by Nothing Phone 2 Pro': 'MediaTek Dimensity 7200 Pro',
    'Samsung Galaxy F16': 'Exynos 1280',
    'POCO X7': 'MediaTek Dimensity 8300 Ultra',
    'OnePlus Nord CE5': 'Qualcomm Snapdragon 7 Gen 3',
    'OPPO K12x  with 45W SUPERVOOC Charger In-The-Box': 'Qualcomm Snapdragon 695',
    'Apple iPhone 14': 'Apple A15 Bionic',
    'Google Pixel 8a': 'Google Tensor G3',
    'POCO C61': 'Unisoc T612',
    'Apple iPhone 15': 'Apple A16 Bionic',
    'Apple iPhone 15 Plus': 'Apple A16 Bionic',
    'Motorola g04s': 'Unisoc T606',
    'POCO C51 - Locked with Airtel Prepaid': 'MediaTek Helio G36',
    'Motorola e40': 'Unisoc T700',
    'realme C51': 'Unisoc T612',
    'Motorola G34': 'Qualcomm Snapdragon 695',
    'Infinix Smart 7 HD': 'Unisoc SC9863A',
    'POCO M6 Pro': 'Qualcomm Snapdragon 4 Gen 2',
    'Apple iPhone 14 Plus': 'Apple A15 Bionic',
    'Motorola Edge 40 Neo': 'MediaTek Dimensity 7030',
    'Ai+ Pulse': 'Unisoc T615',
    'POCO C75': 'Unisoc T606',
    'POCO M7': 'MediaTek Helio G99',
    'MOTOROLA g35': 'MediaTek Helio G35',
    'MOTOROLA G86 Power': 'Qualcomm Snapdragon 695',
    'MOTOROLA Edge 60 Pro': 'Qualcomm Snapdragon 8 Gen 2',
    'MOTOROLA Edge 60 Stylus': 'Qualcomm Snapdragon 7 Gen 2',
    'OPPO K13x  6000mAh and 45W SUPERVOOC Charger & AI': 'MediaTek Dimensity 6100+',
    'REDMI A3X': 'Unisoc T606',
    'POCO M7 Pro': 'MediaTek Helio G99',
    'Nothing Phone': 'Qualcomm Snapdragon 8+ Gen 1',
    'vivo V25': 'MediaTek Dimensity 900',
    'Tecno Pova 7': 'MediaTek Helio G99',
    'Samsung M05': 'Exynos 850',
    'Motorola g64': 'MediaTek Dimensity 7020',
    'Tecno Pova 6 Neo': 'MediaTek Helio G99',
    'Apple iPhone 16 Pro Max': 'Apple A18 Pro',
    'Apple iPhone 16': 'Apple A18',
    'POCO F7': 'Qualcomm Snapdragon 8s Gen 3',
    'Samsung Galaxy A35': 'Exynos 1380',
    'Apple iPhone 16e': 'Apple A17 Bionic',
    'Motorola Edge 50 Neo': 'Qualcomm Snapdragon 695',
    'Samsung Galaxy S24 Ultra': 'Qualcomm Snapdragon 8 Gen 3',
    'Motorola Edge 50 Pro  with 125W Charger': 'Qualcomm Snapdragon 7 Gen 1',
    'IQOO Neo 10R': 'Qualcomm Snapdragon 8s Gen 3',
    'Infinix Note 50s +': 'MediaTek Helio G99',
    'OnePlus Nord CE4 lite': 'Qualcomm Snapdragon 695',
    'Samsung Galaxy S24 FE': 'Qualcomm Snapdragon 8 Gen 2',
    'Samsung Galaxy A55': 'Exynos 1480',
    'Apple iPhone 16 Plus': 'Apple A18',
    'Samsung Galaxy S24': 'Qualcomm Snapdragon 8 Gen 3',
    'Ai+ Nova': 'Unknown',
    'REDMI A4  only on Jio SIM': 'Unisoc T606',
    'realme Narzo 80 Lite 4G': 'Unisoc T612',
    'Infinix Hot 60 +': 'MediaTek Helio G88',
    'Google Pixel 9': 'Google Tensor G4',
    'REDMI 13': 'MediaTek Helio G88',
    'realme Narzo 80 Lite': 'Unisoc T612',
    'vivo Y19e': 'MediaTek Helio P65',
    'MOTOROLA Edge 50': 'Qualcomm Snapdragon 7 Gen 2',
    'Infinix Note 50x +': 'MediaTek Helio G99',
    'realme 14x': 'MediaTek Dimensity 6100+',
    'realme P3 Ultra': 'MediaTek Dimensity 7050',
    'Samsung Galaxy F36': 'Exynos 1280',
    'OnePlus Nord 5': 'Qualcomm Snapdragon 8 Gen 2',
    'Infinix GT 30 Pro +': 'MediaTek Helio G99',
    'IQOO Z10 Lite': 'Qualcomm Snapdragon 6 Gen 1',
    'Apple iPhone 16 Pro': 'Apple A18 Pro',
    'vivo T3': 'MediaTek Dimensity 8200',
    'REDMI Note 14 SE': 'MediaTek Helio G99',
    'OnePlus 13R': 'Qualcomm Snapdragon 8s Gen 3',
    'Samsung Galaxy S24+': 'Qualcomm Snapdragon 8 Gen 3',
    'IQOO Z10': 'Qualcomm Snapdragon 6 Gen 1',
    'itel P55': 'Unisoc T606',
    'Tecno Spark Go 1': 'MediaTek Helio A22',
    'POCO M7  - Locked with Airtel Prepaid': 'MediaTek Helio G99',
    'itel ZENO 10': 'Unisoc T606',
    'Motorola g84': 'Qualcomm Snapdragon 695',
    'REDMI 13C': 'MediaTek Helio G85',
    'LAVA YUVA STAR 2': 'Unisoc SC9832E',
    'itel A80': 'Unisoc SC9863A',
    'SIAVANTAGE Pro 4': 'Unknown',
    'realme 14T': 'Unknown',
    'Samsung Galaxy F15': 'MediaTek Dimensity 6100+',
    'Samsung Galaxy F34': 'Exynos 1280',
    'REDMI A3': 'Unisoc T606',
    'REDMI 12': 'MediaTek Helio G88',
    'realme C55': 'MediaTek Helio G88',
    'vivo T2 Pro': 'MediaTek Dimensity 7200',
    'Samsung Galaxy A05s': 'Qualcomm Snapdragon 680',
    'Samsung Galaxy Z Flip5': 'Qualcomm Snapdragon 8 Gen 2',
    'OPPO Reno14': 'MediaTek Dimensity 7050',
    'Tecno Pova 7 Pro': 'MediaTek Helio G99',
    'Infinix Smart 2': 'MediaTek MT6580',
    'GIONEE Max': 'Unisoc SC9863A',
    'Motorola g73': 'MediaTek Dimensity 930',
    'Samsung Galaxy Z Fold5': 'Qualcomm Snapdragon 8 Gen 2',
    'Infinix Hot 12 Pro': 'Unisoc T616',
    'Motorola Edge 50 Pro  with 68W Charger': 'Qualcomm Snapdragon 7 Gen 1',
    'Motorola g72': 'MediaTek Helio G99',
    'REDMI Note 12': 'Qualcomm Snapdragon 4 Gen 1',
    'LAVA Blaze 2  with Dual Sim|50MP Rear Camera|5000 mAh Battery|Expandable Upto 1 TB': 'Unisoc T616',
    'POCO F6': 'Qualcomm Snapdragon 8s Gen 3',
    'Infinix Hot 10S': 'MediaTek Helio G85',
    'LAVA BLAZE 2': 'Unisoc T616',
    'LAVA Z60': 'Unknown',
    'itel A25 Pro': 'Unisoc SC9832E',
    'LAVA Z1s': 'Mediatek MT6739',
    'Samsung Galaxy On Nxt': 'Exynos 7870',
    'Infinix Smart 6': 'Unisoc SC9863A',
    'POCO M5': 'MediaTek Helio G99',
    'Tecno Camon 20': 'MediaTek Helio G85',
    'XOLO ERA 1X -4G with VoLTE': 'Spreadtrum SC9832A',
    'Panasonic Eluga Ray 700': 'MediaTek MTK6753',
    'Infinix Hot 10': 'MediaTek Helio G70',
    'Lenovo Phab 2': 'MediaTek MT8735',
    'LG Q6+': 'Qualcomm Snapdragon 435',
    'Samsung Galaxy S25': 'Qualcomm Snapdragon 8 Gen 3',
    'REDMI A5': 'MediaTek Helio G25',
    'Google Pixel 9A': 'Google Tensor G4',
    'POCO X7 Pro': 'MediaTek Dimensity 9200+',
    'IQOO Z10R': 'Qualcomm Snapdragon 6 Gen 1',
    'IQOO Neo 10': 'Qualcomm Snapdragon 8 Gen 1',
    'realme 15 Pro': 'MediaTek Dimensity 9200+',
    'realme 15': 'MediaTek Dimensity 9200+',
    'realme Narzo 80x': 'Dimensity 6100+',
    'Snexian BOLD T240': 'Unknown',
    'realme C75': 'Unisoc T616',
    'Tecno POP 9': 'Unisoc T606',
    'POCO C71  - Locked with Airtel Prepaid': 'Unisoc T7250',
    'vivo X200 FE': 'MediaTek Dimensity 9200+',
    'realme 12+': 'MediaTek Dimensity 6020+',
    'Samsung Galaxy M16': 'MediaTek Helio G80',
    'vivo T3 Pro': 'MediaTek Dimensity 9200+',
    'Infinix SMART 10': 'Unisoc T606',
    'MOTOROLA Razr 60': 'MediaTek Dimensity 6020+',
    'Samsung Galaxy A16': 'MediaTek Helio G80',
    'OnePlus Nord CE4': 'Qualcomm Snapdragon 695',
    'itel P 55': 'Unisoc T606',
    'Samsung M36': 'MediaTek Helio G80',
    'realme C73': 'Unisoc T616',
    'Samsung Galaxy A06': 'MediaTek Helio G37',
    'realme P3 Pro': 'MediaTek Dimensity 9650+',
    'realme P1 Speed': 'MediaTek Dimensity 9200',
    'Samsung Galaxy M35': 'MediaTek Helio G80',
    'REDMI Note 14': 'MediaTek Helio G99',
    'vivo Y36': 'MediaTek Helio G96',
    'Samsung Galaxy Z Fold6': 'Qualcomm Snapdragon 8 Gen 3',
    'OPPO F29': 'MediaTek Dimensity 6100+',
    'OPPO A3x': 'MediaTek Helio P22',
    'realme C63  Charger in the Box': 'Unisoc T616',
    'vivo Y22': 'MediaTek Helio G85',
    'realme GT 6': 'MediaTek Dimensity 9200+',
    'realme P2 Pro': 'MediaTek Dimensity 8100+',
    'REDMI A4': 'Unisoc T606',
    'Honor 200': 'Unisoc T610',
    'Tecno Pova Curve': 'MediaTek Helio G99',
    'vivo V50e': 'MediaTek Dimensity 900',
    'vivo T3 Lite': 'MediaTek Dimensity 6100+',
    'OPPO A17k': 'MediaTek Helio G25',
    'POCO M7   - Locked with Airtel Prepaid': 'MediaTek Helio G99',
    'REDMI 14C': 'MediaTek Helio G35',
    'Samsung Galaxy A36': 'MediaTek Helio G80',
    'POCO M6 Plus': 'MediaTek Helio G99',
    'vivo T4 Ultra': 'MediaTek Dimensity 8200',
    'LAVA Yuva Smart': 'Unisoc SC9832E',
    'realme 14 Pro': 'MediaTek Dimensity 9200+',
    'Samsung M06': 'Exynos 850',
    'REDMI 13  Prime Edition': 'MediaTek Helio G88',
    'realme 13 Pro+': 'MediaTek Dimensity 9200+',
    'Samsung Galaxy A15': 'MediaTek Helio G37',
    'realme NARZO 80 Pro': 'MediaTek Helio G99',
    'realme 14 Pro Lite': 'MediaTek Dimensity 6020+',
    'Infinix Note 40': 'MediaTek Helio G85',
    'Samsung Galaxy A56': 'Exynos 1380',
    'LAVA Yuva 2': 'Unisoc SC9832E',
    'realme 14 Pro+': 'MediaTek Dimensity 9200+',
    'Tecno Camon 30': 'MediaTek Helio G85',
    'Motorola Edge 50 Ultra': 'Qualcomm Snapdragon 8 Gen 1',
    'realme Narzo N61': 'MediaTek Helio G99',
    'IQOO z9x': 'Qualcomm Snapdragon 8 Gen 2',
    'Infinix Hot 50': 'MediaTek Helio G88',
    'Xiaomi 14 CIVI': 'Qualcomm Snapdragon 8 Gen 2',
    'OPPO K13 Turbo Pro': 'MediaTek Dimensity 8200',
    'OnePlus Nord 5�': 'Qualcomm Snapdragon 8 Gen 2',
    'Motorola g54': 'MediaTek Dimensity 930',
    'Samsung Galaxy S23 Ultra': 'Qualcomm Snapdragon 8 Gen 2',
    'IQOO Z9s': 'Qualcomm Snapdragon 8 Gen 2',
    'vivo X200 Pro': 'MediaTek Dimensity 9200+',
    'Samsung Galaxy S25 Ultra': 'Qualcomm Snapdragon 8 Gen 3',
    'OPPO Reno14 Pro': 'MediaTek Dimensity 9200+',
    'OnePlus 13s': 'Qualcomm Snapdragon 8 Gen 2',
    'vivo V60': 'MediaTek Dimensity 8200',
    'Samsung Galaxy M56': 'MediaTek Helio G80',
    'vivo T3 Ultra': 'MediaTek Dimensity 9200+',
    'Samsung Galaxy F13': 'MediaTek Helio G85',
    'vivo Y400': 'MediaTek Dimensity 930',
    'itel A50': 'Unisoc T606',
    'CMF by Nothing Phone 1': 'Qualcomm Snapdragon 778G',
    'Infinix Note 11': 'MediaTek Helio G88',
    'realme Gt 7': 'MediaTek Dimensity 9200+',
    'Samsung Galaxy A25': 'MediaTek Helio G80',
    'vivo V50': 'MediaTek Dimensity 9200+',
    'Tecno Camon 20 Pro': 'MediaTek Helio G95',
    'vivo Y18t': 'MediaTek Helio G85',
    'Samsung A16': 'MediaTek Helio G80',
    'LAVA Yuva Star': 'Unisoc SC9832E',
    'OPPO F29 Pro': 'MediaTek Dimensity 9200+',
    'vivo Y400 Pro': 'MediaTek Dimensity 930',
    'REDMI 13c': 'MediaTek Helio G85',
    'Samsung Galaxy S23': 'Qualcomm Snapdragon 8 Gen 2',
    'Samsung Galaxy Z Flip6': 'Qualcomm Snapdragon 8 Gen 3',
    'REDMI Note 13 Pro': 'MediaTek Dimensity 9200+',
    'Motorola G32': 'Unisoc T606',
    'Google Pixel 7': 'Google Tensor G2',
    'vivo Y19': 'Mediatek Helio P65',
    'itel A90': 'Unisoc T606',
    'Google Pixel 9 Pro Fold': 'Google Tensor G4',
    'vivo Y300 Plus': 'MediaTek Dimensity 930',
    'realme P1': 'MediaTek Dimensity 9200+',
    'REDMI Note-14 Pro+': 'MediaTek Dimensity 9200+',
    'Samsung GALAXY M13': 'Exynos 850',
    'Samsung Galaxy A26': 'MediaTek Helio G80',
    'POCO X6': 'Qualcomm Snapdragon 4 Gen 1',
    'REDMI 9 Power': 'Qualcomm Snapdragon 662',
    'REDMI Note 14 Pro+': 'MediaTek Dimensity 9200+',
    'Google Pixel 8 Pro': 'Google Tensor G3',
    'Samsung Galaxy A23': 'MediaTek Helio G80',
    'Google Pixel 9 Pro XL': 'Google Tensor G4',
    'Tecno Spark 30C': 'MediaTek Helio G85',
    'IQOO Z9x': 'Qualcomm Snapdragon 6 Gen 1',
    'IQOO Z9S PRO': 'Qualcomm Snapdragon 7 Gen 2',
    'POCO X6 Neo': 'MediaTek Dimensity 1080',
    'POCO X6 Pro': 'Qualcomm Snapdragon 4 Gen 1',
    'realme 13 Pro': 'MediaTek Dimensity 9200+',
    'OnePlus 13': 'Qualcomm Snapdragon 8 Gen 2',
    'Samsung Galaxy A14': 'MediaTek Helio G80',
    'POCO C51': 'MediaTek Helio G36',
    'Redmi Note 8': 'Qualcomm Snapdragon 665',
    'vivo Y100A': 'MediaTek Helio G80',
    'Samsung M55s': 'MediaTek Helio G80',
    'Mi 10T': 'Qualcomm Snapdragon 865',
    'vivo Y29': 'MediaTek Helio G88',
    'Samsung Galaxy S23 FE': 'Qualcomm Snapdragon 8 Gen 2',
    'Samsung Galaxy A04': 'MediaTek Helio P35',
    'realme 70 TURBO': 'MediaTek Dimensity 9200+',
    'vivo Y28s': 'MediaTek Helio G80',
    'realme Narzo 80 Pro': 'MediaTek Helio G99',
    'REDMI Note 14 Pro': 'MediaTek Helio G99',
    'LAVA Yuva Star': 'Unisoc SC9832E',
    'REDMI Note 14 Pro': 'MediaTek Helio G99',
    'vivo Y18i': 'MediaTek Helio G85',
    'Samsung Galaxy Z Flip6': 'Qualcomm Snapdragon 8 Gen 3',
    'vivo Y18t': 'MediaTek Helio G85',
    'vivo Y22': 'MediaTek Helio G85',
    'realme 70 TURBO': 'MediaTek Dimensity 9200+',
    'Motorola G62': 'MediaTek Helio G37',
    'Samsung Galaxy F23': 'MediaTek Helio G96',
    'Samsung Glaxy S25 Plus': 'Qualcomm Snapdragon 8 Gen 3',
    'Micromax IN Note 1': 'MediaTek Helio G85',
    'OPPO A5 Pro': 'MediaTek Helio P35',
    'itel A50C': 'Unisoc T606',
    'Samsung galaxy M15': 'MediaTek Helio G80',
    'REDMI Note 14 Pro+': 'MediaTek Dimensity 9200+',
    'itel Color Pro': 'Unisoc T616',
    'OPPO A3 Pro': 'MediaTek Helio P35',
    'realme Narzo N65': 'MediaTek Helio G85',
    'vivo V40 Pro': 'MediaTek Dimensity 9200+',
    'itel A90': 'Unisoc T606',
    'Samsung Galaxy Z Flip5': 'Qualcomm Snapdragon 8 Gen 2',
    'itel A80': 'Unisoc SC9863A',
    'OPPO F27': 'MediaTek Dimensity 6100+',
    'REDMI Note-14 Pro+': 'MediaTek Dimensity 9200+',
    'REDMI Note 14 Pro': 'MediaTek Helio G99',
    'Samsung Galaxy A36': 'MediaTek Helio G80',
    'realme P1': 'MediaTek Dimensity 9200+',
    'vivo Y100A': 'MediaTek Helio G80',
}

a=list(processor_map.keys())
b=list(processor_map.values())
dic={
    'model_name':a,
    'processor1':b
}
temp=pd.DataFrame(dic)

# %%
df.loc[:,'model_name']=df['model_name'].str.strip()

# %%
df=df.merge(temp,how='left',on='model_name')

# %%
df
# Out:
#         brand               model_name    color   price 5G_flag  avg_rating  \
# 0    MOTOROLA             MOTOROLA g05    Green    6999      NO         4.2
# 1        POCO                 POCO C71     Gold    6999      NO         4.1
# 2        POCO                 POCO C71     Blue    6399      NO         3.9
# 3     SAMSUNG       Samsung Galaxy F05     Blue    6499      NO         4.2
# 4    MOTOROLA  MOTOROLA Edge 60 Fusion  pantone   22999     YES         4.5
# ..        ...                      ...      ...     ...     ...         ...
# 815   SAMSUNG       Samsung Galaxy A36    Black   30999     YES         4.3
# 816    GOOGLE    Google Pixel 9 Pro XL    Other  119999      NO         4.6
# 817     REDMI       REDMI Note-14 Pro+   Purple   26249     YES         4.2
# 818    REALME                realme P1    Green   13000     YES         4.4
# 819      VIVO               vivo Y100A     Gold   18999      NO         4.3
#
# ...

# %%
 # df.drop(columns='processor1',inplace=True)

# %%
list(df[df['processor1'].isnull()]['model_name'].unique())
# Out:
# []

# %%
# df[df['model_name']=='OnePlus Nord 5�']

# %%
official_model_names = {
    'MOTOROLA g05': 'Moto G05',
    'POCO C71': 'POCO C71',
    'Samsung Galaxy F05': 'Samsung Galaxy F05',
    'MOTOROLA Edge 60 Fusion': 'Motorola Edge 60 Fusion',
    'Motorola G85': 'Moto G85',
    'vivo T4 Lite  Charger in the Box': 'Vivo T4 Lite',
    'MOTOROLA Edge 60': 'Motorola Edge 60',
    'vivo T4R': 'Vivo T4R',
    'Motorola g45': 'Moto G45',
    'vivo T4x': 'Vivo T4x',
    'Samsung Galaxy F06': 'Samsung Galaxy F06',
    'Motorola Edge 50 Fusion': 'Motorola Edge 50 Fusion',
    'Tecno Spark Go 2': 'Tecno Spark Go 2',
    'MOTOROLA G96': 'Moto G96',
    'realme C61': 'Realme C61',
    'vivo T4': 'Vivo T4',
    'Infinix SMART 9 HD': 'Infinix Smart 9 HD',
    'IQOO Z10X': 'iQOO Z10x',
    'CMF by Nothing Phone 2 Pro': 'Nothing Phone (2) Pro',
    'Samsung Galaxy F16': 'Samsung Galaxy F16',
    'POCO X7': 'POCO X7',
    'OnePlus Nord CE5': 'OnePlus Nord CE5',
    'OPPO K12x  with 45W SUPERVOOC Charger In-The-Box': 'OPPO K12x',
    'Apple iPhone 14': 'Apple iPhone 14',
    'Google Pixel 8a': 'Google Pixel 8a',
    'POCO C61': 'POCO C61',
    'Apple iPhone 15': 'Apple iPhone 15',
    'Apple iPhone 15 Plus': 'Apple iPhone 15 Plus',
    'Motorola g04s': 'Moto G4s',
    'POCO C51 - Locked with Airtel Prepaid': 'POCO C51',
    'Motorola e40': 'Moto e40',
    'realme C51': 'Realme C51',
    'Motorola G34': 'Moto G34',
    'Infinix Smart 7 HD': 'Infinix Smart 7 HD',
    'POCO M6 Pro': 'POCO M6 Pro',
    'Apple iPhone 14 Plus': 'Apple iPhone 14 Plus',
    'Motorola Edge 40 Neo': 'Motorola Edge 40 Neo',
    'Ai+ Pulse': 'Ai+ Pulse',
    'POCO C75': 'POCO C75',
    'POCO M7': 'POCO M7',
    'MOTOROLA g35': 'Moto G35',
    'MOTOROLA G86 Power': 'Moto G86 Power',
    'MOTOROLA Edge 60 Pro': 'Motorola Edge 60 Pro',
    'MOTOROLA Edge 60 Stylus': 'Motorola Edge 60 Stylus',
    'OPPO K13x  6000mAh and 45W SUPERVOOC Charger & AI': 'OPPO K13x',
    'REDMI A3X': 'Redmi A3X',
    'POCO M7 Pro': 'POCO M7 Pro',
    'Nothing Phone': 'Nothing Phone (1)',
    'vivo V25': 'Vivo V25',
    'Tecno Pova 7': 'Tecno Pova 7',
    'Samsung M05': 'Samsung Galaxy M05',
    'Motorola g64': 'Moto G64',
    'Tecno Pova 6 Neo': 'Tecno Pova 6 Neo',
    'Apple iPhone 16 Pro Max': 'Apple iPhone 16 Pro Max',
    'Apple iPhone 16': 'Apple iPhone 16',
    'POCO F7': 'POCO F7',
    'Samsung Galaxy A35': 'Samsung Galaxy A35',
    'Apple iPhone 16e': 'Apple iPhone 16e',
    'Motorola Edge 50 Neo': 'Motorola Edge 50 Neo',
    'Samsung Galaxy S24 Ultra': 'Samsung Galaxy S24 Ultra',
    'Motorola Edge 50 Pro  with 125W Charger': 'Motorola Edge 50 Pro',
    'IQOO Neo 10R': 'iQOO Neo 10R',
    'Infinix Note 50s +': 'Infinix Note 50s+',
    'OnePlus Nord CE4 lite': 'OnePlus Nord CE4 Lite',
    'Samsung Galaxy S24 FE': 'Samsung Galaxy S24 FE',
    'Samsung Galaxy A55': 'Samsung Galaxy A55',
    'Apple iPhone 16 Plus': 'Apple iPhone 16 Plus',
    'Samsung Galaxy S24': 'Samsung Galaxy S24',
    'Ai+ Nova': 'Ai+ Nova',
    'REDMI A4  only on Jio SIM': 'Redmi A4',
    'realme Narzo 80 Lite 4G': 'Realme Narzo 80 Lite 4G',
    'Infinix Hot 60 +': 'Infinix Hot 60+',
    'Google Pixel 9': 'Google Pixel 9',
    'REDMI 13': 'Redmi 13',
    'realme Narzo 80 Lite': 'Realme Narzo 80 Lite',
    'vivo Y19e': 'Vivo Y19e',
    'MOTOROLA Edge 50': 'Motorola Edge 50',
    'Infinix Note 50x +': 'Infinix Note 50x+',
    'realme 14x': 'Realme 14x',
    'realme P3 Ultra': 'Realme P3 Ultra',
    'Samsung Galaxy F36': 'Samsung Galaxy F36',
    'OnePlus Nord 5': 'OnePlus Nord 5',
    'Infinix GT 30 Pro +': 'Infinix GT 30 Pro+',
    'IQOO Z10 Lite': 'iQOO Z10 Lite',
    'Apple iPhone 16 Pro': 'Apple iPhone 16 Pro',
    'vivo T3': 'Vivo T3',
    'REDMI Note 14 SE': 'Redmi Note 14 SE',
    'OnePlus 13R': 'OnePlus 13R',
    'Samsung Galaxy S24+': 'Samsung Galaxy S24+',
    'IQOO Z10': 'iQOO Z10',
    'itel P55': 'itel P55',
    'Tecno Spark Go 1': 'Tecno Spark Go 1',
    'POCO M7  - Locked with Airtel Prepaid': 'POCO M7',
    'itel ZENO 10': 'itel Zeno 10',
    'Motorola g84': 'Moto G84',
    'REDMI 13C': 'Redmi 13C',
    'LAVA YUVA STAR 2': 'Lava Yuva Star 2',
    'itel A80': 'itel A80',
    'SIAVANTAGE Pro 4': 'Siavantage Pro 4',
    'realme 14T': 'Realme 14T',
    'Samsung Galaxy F15': 'Samsung Galaxy F15',
    'Samsung Galaxy F34': 'Samsung Galaxy F34',
    'REDMI A3': 'Redmi A3',
    'REDMI 12': 'Redmi 12',
    'realme C55': 'Realme C55',
    'vivo T2 Pro': 'Vivo T2 Pro',
    'Samsung Galaxy A05s': 'Samsung Galaxy A05s',
    'Samsung Galaxy Z Flip5': 'Samsung Galaxy Z Flip5',
    'OPPO Reno14': 'OPPO Reno14',
    'Tecno Pova 7 Pro': 'Tecno Pova 7 Pro',
    'Infinix Smart 2': 'Infinix Smart 2',
    'GIONEE Max': 'Gionee Max',
    'Motorola g73': 'Moto G73',
    'Samsung Galaxy Z Fold5': 'Samsung Galaxy Z Fold5',
    'Infinix Hot 12 Pro': 'Infinix Hot 12 Pro',
    'Motorola Edge 50 Pro  with 68W Charger': 'Motorola Edge 50 Pro',
    'Motorola g72': 'Moto G72',
    'REDMI Note 12': 'Redmi Note 12',
    'LAVA Blaze 2  with Dual Sim|50MP Rear Camera|5000 mAh Battery|Expandable Upto 1 TB': 'Lava Blaze 2',
    'POCO F6': 'POCO F6',
    'Infinix Hot 10S': 'Infinix Hot 10S',
    'LAVA BLAZE 2': 'Lava Blaze 2',
    'LAVA Z60': 'Lava Z60',
    'itel A25 Pro': 'itel A25 Pro',
    'LAVA Z1s': 'Lava Z1s',
    'Samsung Galaxy On Nxt': 'Samsung Galaxy On Nxt',
    'Infinix Smart 6': 'Infinix Smart 6',
    'POCO M5': 'POCO M5',
    'Tecno Camon 20': 'Tecno Camon 20',
    'XOLO ERA 1X -4G with VoLTE': 'XOLO ERA 1X',
    'Panasonic Eluga Ray 700': 'Panasonic Eluga Ray 700',
    'Infinix Hot 10': 'Infinix Hot 10',
    'Lenovo Phab 2': 'Lenovo Phab 2',
    'LG Q6+': 'LG Q6+',
    'Samsung Galaxy S25': 'Samsung Galaxy S25',
    'REDMI A5': 'Redmi A5',
    'Google Pixel 9A': 'Google Pixel 9a',
    'POCO X7 Pro': 'POCO X7 Pro',
    'IQOO Z10R': 'iQOO Z10R',
    'IQOO Neo 10': 'iQOO Neo 10',
    'realme 15 Pro': 'Realme 15 Pro',
    'realme 15': 'Realme 15',
    'realme Narzo 80x': 'Realme Narzo 80x',
    'Snexian BOLD T240': 'Snexian BOLD T240',
    'realme C75': 'Realme C75',
    'Tecno POP 9': 'Tecno POP 9',
    'POCO C71  - Locked with Airtel Prepaid': 'POCO C71',
    'vivo X200 FE': 'Vivo X200 FE',
    'realme 12+': 'Realme 12+',
    'Samsung Galaxy M16': 'Samsung Galaxy M16',
    'vivo T3 Pro': 'Vivo T3 Pro',
    'Infinix SMART 10': 'Infinix Smart 10',
    'MOTOROLA Razr 60': 'Motorola Razr 60',
    'Samsung Galaxy A16': 'Samsung Galaxy A16',
    'OnePlus Nord CE4': 'OnePlus Nord CE4',
    'itel P 55': 'itel P55',
    'Samsung M36': 'Samsung M36',
    'realme C73': 'Realme C73',
    'Samsung Galaxy A06': 'Samsung Galaxy A06',
    'realme P3 Pro': 'Realme P3 Pro',
    'realme P1 Speed': 'Realme P1 Speed',
    'Samsung Galaxy M35': 'Samsung Galaxy M35',
    'REDMI Note 14': 'Redmi Note 14',
    'vivo Y36': 'Vivo Y36',
    'Samsung Galaxy Z Fold6': 'Samsung Galaxy Z Fold6',
    'OPPO F29': 'OPPO F29',
    'OPPO A3x': 'OPPO A3x',
    'realme C63  Charger in the Box': 'Realme C63',
    'vivo Y22': 'Vivo Y22',
    'realme GT 6': 'Realme GT 6',
    'realme P2 Pro': 'Realme P2 Pro',
    'REDMI A4': 'Redmi A4',
    'Honor 200': 'Honor 200',
    'Tecno Pova Curve': 'Tecno Pova Curve',
    'vivo V50e': 'Vivo V50e',
    'vivo T3 Lite': 'Vivo T3 Lite',
    'OPPO A17k': 'OPPO A17k',
    'POCO M7   - Locked with Airtel Prepaid': 'POCO M7',
    'REDMI 14C': 'Redmi 14C',
    'Samsung Galaxy A36': 'Samsung Galaxy A36',
    'POCO M6 Plus': 'POCO M6 Plus',
    'vivo T4 Ultra': 'Vivo T4 Ultra',
    'LAVA Yuva Smart': 'Lava Yuva Smart',
    'realme 14 Pro': 'Realme 14 Pro',
    'Samsung M06': 'Samsung Galaxy M06',
    'REDMI 13  Prime Edition': 'Redmi 13 Prime Edition',
    'realme 13 Pro+': 'Realme 13 Pro+',
    'Samsung Galaxy A15': 'Samsung Galaxy A15',
    'realme NARZO 80 Pro': 'Realme Narzo 80 Pro',
    'realme 14 Pro Lite': 'Realme 14 Pro Lite',
    'Infinix Note 40': 'Infinix Note 40',
    'Samsung Galaxy A56': 'Samsung Galaxy A56',
    'LAVA Yuva 2': 'Lava Yuva 2',
    'realme 14 Pro+': 'Realme 14 Pro+',
    'Tecno Camon 30': 'Tecno Camon 30',
    'Motorola Edge 50 Ultra': 'Motorola Edge 50 Ultra',
    'realme Narzo N61': 'Realme Narzo N61',
    'IQOO z9x': 'iQOO Z9x',
    'Infinix Hot 50': 'Infinix Hot 50',
    'Xiaomi 14 CIVI': 'Xiaomi 14 CIVI',
    'OPPO K13 Turbo Pro': 'OPPO K13 Turbo Pro',
    'OnePlus Nord 5�': 'OnePlus Nord 5',
    'Motorola g54': 'Moto G54',
    'Samsung Galaxy S23 Ultra': 'Samsung Galaxy S23 Ultra',
    'IQOO Z9s': 'iQOO Z9s',
    'vivo X200 Pro': 'Vivo X200 Pro',
    'Samsung Galaxy S25 Ultra': 'Samsung Galaxy S25 Ultra',
    'OPPO Reno14 Pro': 'OPPO Reno14 Pro',
    'OnePlus 13s': 'OnePlus 13s',
    'vivo V60': 'Vivo V60',
    'Samsung Galaxy M56': 'Samsung Galaxy M56',
    'vivo T3 Ultra': 'Vivo T3 Ultra',
    'Samsung Galaxy F13': 'Samsung Galaxy F13',
    'vivo Y400': 'Vivo Y400',
    'itel A50': 'itel A50',
    'CMF by Nothing Phone 1': 'Nothing Phone 1',
    'Infinix Note 11': 'Infinix Note 11',
    'realme Gt 7': 'Realme GT 7',
    'Samsung Galaxy A25': 'Samsung Galaxy A25',
    'vivo V50': 'Vivo V50',
    'Tecno Camon 20 Pro': 'Tecno Camon 20 Pro',
    'vivo Y18t': 'Vivo Y18t',
    'Samsung A16': 'Samsung Galaxy A16',
    'LAVA Yuva Star': 'Lava Yuva Star',
    'OPPO F29 Pro': 'OPPO F29 Pro',
    'vivo Y400 Pro': 'Vivo Y400 Pro',
    'REDMI 13c': 'Redmi 13c',
    'Samsung Galaxy S23': 'Samsung Galaxy S23',
    'Samsung Galaxy Z Flip6': 'Samsung Galaxy Z Flip6',
    'REDMI Note 13 Pro': 'Redmi Note 13 Pro',
    'Motorola G32': 'Moto G32',
    'Google Pixel 7': 'Google Pixel 7',
    'vivo Y19': 'Vivo Y19',
    'itel A90': 'itel A90',
    'Google Pixel 9 Pro Fold': 'Google Pixel 9 Pro Fold',
    'vivo Y300 Plus': 'Vivo Y300 Plus',
    'realme P1': 'Realme P1',
    'REDMI Note-14 Pro+': 'Redmi Note 14 Pro+',
    'Samsung GALAXY M13': 'Samsung Galaxy M13',
    'Samsung Galaxy A26': 'Samsung Galaxy A26',
    'POCO X6': 'POCO X6',
    'REDMI 9 Power': 'Redmi 9 Power',
    'REDMI Note 14 Pro+': 'Redmi Note 14 Pro+',
    'Google Pixel 8 Pro': 'Google Pixel 8 Pro',
    'Samsung Galaxy A23': 'Samsung Galaxy A23',
    'Google Pixel 9 Pro XL': 'Google Pixel 9 Pro XL',
    'Tecno Spark 30C': 'Tecno Spark 30C',
    'IQOO Z9x': 'iQOO Z9x',
    'IQOO Z9S PRO': 'iQOO Z9s Pro',
    'POCO X6 Neo': 'POCO X6 Neo',
    'POCO X6 Pro': 'POCO X6 Pro',
    'realme 13 Pro': 'Realme 13 Pro',
    'OnePlus 13': 'OnePlus 13',
    'Samsung Galaxy A14': 'Samsung Galaxy A14',
    'POCO C51': 'POCO C51',
    'Redmi Note 8': 'Redmi Note 8',
    'vivo Y100A': 'Vivo Y100A',
    'Samsung M55s': 'Samsung Galaxy M55s',
    'Mi 10T': 'Xiaomi Mi 10T',
    'vivo Y29': 'Vivo Y29',
    'Samsung Galaxy S23 FE': 'Samsung Galaxy S23 FE',
    'Samsung Galaxy A04': 'Samsung Galaxy A04',
    'realme 70 TURBO': 'Realme 70 Turbo',
    'vivo Y28s': 'Vivo Y28s',
    'realme Narzo 80 Pro': 'Realme Narzo 80 Pro',
    'REDMI Note 14 Pro': 'Redmi Note 14 Pro',
    'LAVA Yuva Star': 'Lava Yuva Star',
    'REDMI Note 14 Pro': 'Redmi Note 14 Pro',
    'vivo Y18i': 'Vivo Y18i',
    'Samsung Galaxy Z Flip6': 'Samsung Galaxy Z Flip6',
    'vivo Y18t': 'Vivo Y18t',
    'vivo Y22': 'Vivo Y22',
    'realme 70 TURBO': 'Realme 70 Turbo',
    'Motorola G62': 'Moto G62',
    'Samsung Galaxy F23': 'Samsung Galaxy F23',
    'Samsung Glaxy S25 Plus': 'Samsung Galaxy S25 Plus',
    'Micromax IN Note 1': 'Micromax IN Note 1',
    'vivo Y100A': 'Vivo Y100A',
    'Samsung Galaxy S25 Ultra': 'Samsung Galaxy S25 Ultra',
    'OPPO A5 Pro': 'OPPO A5 Pro',
    'itel A50C': 'itel A50C',
    'Samsung galaxy M15': 'Samsung Galaxy M15',
    'REDMI Note 14 Pro+': 'Redmi Note 14 Pro+',
    'itel Color Pro': 'itel Color Pro',
    'OPPO A3 Pro': 'OPPO A3 Pro',
    'realme Narzo N65': 'Realme Narzo N65',
    'vivo V40 Pro': 'Vivo V40 Pro',
    'itel A90': 'itel A90',
    'Samsung Galaxy Z Flip5': 'Samsung Galaxy Z Flip5',
    'itel A80': 'itel A80',
    'OPPO F27': 'OPPO F27',
    'REDMI Note-14 Pro+': 'Redmi Note 14 Pro+',
    'REDMI Note 14 Pro': 'Redmi Note 14 Pro',
    'Samsung Galaxy A36': 'Samsung Galaxy A36',
    'realme P1': 'Realme P1',
    'vivo Y100A': 'Vivo Y100A',
}
a=list(official_model_names.keys())
b=list(official_model_names.values())
dic={
    'model_name':a,
    'model_name1':b
}
temp=pd.DataFrame(dic)

# %%
df=df.merge(temp,how='left',on='model_name')

# %%
df
# Out:
#         brand               model_name    color   price 5G_flag  avg_rating  \
# 0    MOTOROLA             MOTOROLA g05    Green    6999      NO         4.2
# 1        POCO                 POCO C71     Gold    6999      NO         4.1
# 2        POCO                 POCO C71     Blue    6399      NO         3.9
# 3     SAMSUNG       Samsung Galaxy F05     Blue    6499      NO         4.2
# 4    MOTOROLA  MOTOROLA Edge 60 Fusion  pantone   22999     YES         4.5
# ..        ...                      ...      ...     ...     ...         ...
# 815   SAMSUNG       Samsung Galaxy A36    Black   30999     YES         4.3
# 816    GOOGLE    Google Pixel 9 Pro XL    Other  119999      NO         4.6
# 817     REDMI       REDMI Note-14 Pro+   Purple   26249     YES         4.2
# 818    REALME                realme P1    Green   13000     YES         4.4
# 819      VIVO               vivo Y100A     Gold   18999      NO         4.3
#
# ...

# %%
list(df[df['model_name1'].isnull()]['model_name'].unique())
# Out:
# []

# %%
df.drop(columns=['model_name','processor'],inplace=True)

# %%
df
# Out:
#         brand    color   price 5G_flag  avg_rating  reviews  battery  RAM  \
# 0    MOTOROLA    Green    6999      NO         4.2    47939     5100    4
# 1        POCO     Gold    6999      NO         4.1    11677     5200    6
# 2        POCO     Blue    6399      NO         3.9    25608     5200    4
# 3     SAMSUNG     Blue    6499      NO         4.2    64333     5000    4
# 4    MOTOROLA  pantone   22999     YES         4.5    48575     5500    8
# ..        ...      ...     ...     ...         ...      ...      ...  ...
# 815   SAMSUNG    Black   30999     YES         4.3     1061     5000    8
# 816    GOOGLE    Other  119999      NO         4.6      877     5060   16
# 817     REDMI   Purple   26249     YES         4.2      177     6200    8
# 818    REALME    Green   13000     YES         4.4    51664     5000    8
# 819      VIVO     Gold   18999      NO         4.3      777     4500    8
#
#      ROM  display_size       display_type                    processor1  \
# ...

# %%
df = df.rename(columns={
    'model_name1': 'model_name',
    'processor1': 'processor'
})

# %%
df
# Out:
#         brand    color   price 5G_flag  avg_rating  reviews  battery  RAM  \
# 0    MOTOROLA    Green    6999      NO         4.2    47939     5100    4
# 1        POCO     Gold    6999      NO         4.1    11677     5200    6
# 2        POCO     Blue    6399      NO         3.9    25608     5200    4
# 3     SAMSUNG     Blue    6499      NO         4.2    64333     5000    4
# 4    MOTOROLA  pantone   22999     YES         4.5    48575     5500    8
# ..        ...      ...     ...     ...         ...      ...      ...  ...
# 815   SAMSUNG    Black   30999     YES         4.3     1061     5000    8
# 816    GOOGLE    Other  119999      NO         4.6      877     5060   16
# 817     REDMI   Purple   26249     YES         4.2      177     6200    8
# 818    REALME    Green   13000     YES         4.4    51664     5000    8
# 819      VIVO     Gold   18999      NO         4.3      777     4500    8
#
#      ROM  display_size       display_type                     processor  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 820 entries, 0 to 819
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         820 non-null    object
#  1   color         820 non-null    object
#  2   price         820 non-null    int64
#  3   5G_flag       820 non-null    object
#  4   avg_rating    820 non-null    float64
#  5   reviews       820 non-null    int64
#  6   battery       820 non-null    int64
#  7   RAM           820 non-null    int64
#  8   ROM           820 non-null    int64
#  9   display_size  820 non-null    float64
#  10  display_type  820 non-null    object
#  11  processor     820 non-null    object
#  12  model_name    820 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 83.4+ KB

# %%
df.duplicated().value_counts()
# Out:
# False    820
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                price  avg_rating        reviews      battery         RAM  \
# count     820.000000  820.000000     820.000000   820.000000  820.000000
# mean    24873.821951    4.321854   22507.134146  5328.590244    7.458537
# std     22536.770801    0.205167   49098.496661   794.684346    2.795774
# min      4399.000000    2.000000       4.000000  2000.000000    1.000000
# 25%     11499.000000    4.200000    1045.750000  5000.000000    6.000000
# 50%     17942.500000    4.300000    3405.000000  5055.000000    8.000000
# 75%     27999.000000    4.400000   18596.000000  6000.000000    8.000000
# max    157900.000000    4.800000  364371.000000  7550.000000   16.000000
#
#               ROM  display_size
# count  820.000000    820.000000
# mean   179.834146     17.223646
# std    105.485270      3.006859
# min      8.000000      7.620000
# 25%    128.000000     16.940000
# 50%    128.000000     17.020000
# 75%    256.000000     17.200000
# max    512.000000     43.660000

# %%
df[df['ROM']==8]
# Out:
#     brand  color  price 5G_flag  avg_rating  reviews  battery  RAM  ROM  \
# 308  XOLO  Black   5149      NO         3.7    49845     2500    1    8
#
#      display_size display_type           processor   model_name
# 308          12.7   HD Display  Spreadtrum SC9832A  XOLO ERA 1X

# %%
df[df['display_size']==41.94]
# Out:
#         brand color  price 5G_flag  avg_rating  reviews  battery  RAM  ROM  \
# 786  MOTOROLA  Blue  11999     YES         4.1    30484     5000    8  128
#
#      display_size       display_type           processor model_name
# 786         41.94   Full HD+ Display  MediaTek Helio G37   Moto G62

# %%
check=df['display_size']==41.94
df.loc[check,'display_size']=16.51

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 820 entries, 0 to 819
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         820 non-null    object
#  1   color         820 non-null    object
#  2   price         820 non-null    int64
#  3   5G_flag       820 non-null    object
#  4   avg_rating    820 non-null    float64
#  5   reviews       820 non-null    int64
#  6   battery       820 non-null    int64
#  7   RAM           820 non-null    int64
#  8   ROM           820 non-null    int64
#  9   display_size  820 non-null    float64
#  10  display_type  820 non-null    object
#  11  processor     820 non-null    object
#  12  model_name    820 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 83.4+ KB

# %%
df['5G_flag']=df['5G_flag'].astype('category')

# %%
df['display_type']=df['display_type'].astype('category')

# %%
list(df['model_name'].unique())
# Out:
# ['Moto G05',
#  'POCO C71',
#  'Samsung Galaxy F05',
#  'Motorola Edge 60 Fusion',
#  'Moto G85',
#  'Vivo T4 Lite',
#  'Motorola Edge 60',
#  'Vivo T4R',
#  'Moto G45',
#  'Vivo T4x',
#  'Samsung Galaxy F06',
#  'Motorola Edge 50 Fusion',
#  'Tecno Spark Go 2',
#  'Moto G96',
#  'Realme C61',
#  'Vivo T4',
#  'Infinix Smart 9 HD',
#  'iQOO Z10x',
#  'Nothing Phone (2) Pro',
#  'Samsung Galaxy F16',
#  'POCO X7',
#  'OnePlus Nord CE5',
#  'OPPO K12x',
#  'Apple iPhone 14',
#  'Google Pixel 8a',
#  'POCO C61',
#  'Apple iPhone 15',
#  'Apple iPhone 15 Plus',
#  'Moto G4s',
#  'POCO C51',
#  'Moto e40',
#  'Realme C51',
#  'Moto G34',
#  'Infinix Smart 7 HD',
#  'POCO M6 Pro',
#  'Apple iPhone 14 Plus',
#  'Motorola Edge 40 Neo',
#  'Ai+ Pulse',
#  'POCO C75',
#  'POCO M7',
#  'Moto G35',
#  'Moto G86 Power',
#  'Motorola Edge 60 Pro',
#  'Motorola Edge 60 Stylus',
#  'OPPO K13x',
#  'Redmi A3X',
#  'POCO M7 Pro',
#  'Nothing Phone (1)',
#  'Vivo V25',
#  'Tecno Pova 7',
# ...

# %%
is_5g = {
    'Moto G05': 'No',
    'POCO C71': 'No',
    'Samsung Galaxy F05': 'No',
    'Motorola Edge 60 Fusion': 'Yes',
    'Moto G85': 'Yes',
    'Vivo T4 Lite': 'No',
    'Motorola Edge 60': 'Yes',
    'Vivo T4R': 'No',
    'Moto G45': 'No',
    'Vivo T4x': 'No',
    'Samsung Galaxy F06': 'No',
    'Motorola Edge 50 Fusion': 'Yes',
    'Tecno Spark Go 2': 'No',
    'Moto G96': 'Yes',
    'Realme C61': 'No',
    'Vivo T4': 'No',
    'Infinix Smart 9 HD': 'No',
    'iQOO Z10x': 'Yes',
    'Nothing Phone (2) Pro': 'Yes',
    'Samsung Galaxy F16': 'Yes',
    'POCO X7': 'Yes',
    'OnePlus Nord CE5': 'Yes',
    'OPPO K12x': 'Yes',
    'Apple iPhone 14': 'Yes',
    'Google Pixel 8a': 'Yes',
    'POCO C61': 'No',
    'Apple iPhone 15': 'Yes',
    'Apple iPhone 15 Plus': 'Yes',
    'Moto G4s': 'No',
    'POCO C51': 'No',
    'Moto e40': 'No',
    'Realme C51': 'No',
    'Moto G34': 'Yes',
    'Infinix Smart 7 HD': 'No',
    'POCO M6 Pro': 'Yes',
    'Apple iPhone 14 Plus': 'Yes',
    'Motorola Edge 40 Neo': 'Yes',
    'Ai+ Pulse': 'No',
    'POCO C75': 'No',
    'POCO M7': 'No',
    'Moto G35': 'No',
    'Moto G86 Power': 'Yes',
    'Motorola Edge 60 Pro': 'Yes',
    'Motorola Edge 60 Stylus': 'Yes',
    'OPPO K13x': 'Yes',
    'Redmi A3X': 'No',
    'POCO M7 Pro': 'Yes',
    'Nothing Phone (1)': 'Yes',
    'Vivo V25': 'Yes',
    'Tecno Pova 7': 'No',
    'Samsung Galaxy M05': 'No',
    'Moto G64': 'Yes',
    'Tecno Pova 6 Neo': 'No',
    'Apple iPhone 16 Pro Max': 'Yes',
    'Apple iPhone 16': 'Yes',
    'POCO F7': 'Yes',
    'Samsung Galaxy A35': 'Yes',
    'Apple iPhone 16e': 'Yes',
    'Motorola Edge 50 Neo': 'Yes',
    'Samsung Galaxy S24 Ultra': 'Yes',
    'Motorola Edge 50 Pro': 'Yes',
    'iQOO Neo 10R': 'Yes',
    'Infinix Note 50s+': 'Yes',
    'OnePlus Nord CE4 Lite': 'Yes',
    'Samsung Galaxy S24 FE': 'Yes',
    'Samsung Galaxy A55': 'Yes',
    'Apple iPhone 16 Plus': 'Yes',
    'Samsung Galaxy S24': 'Yes',
    'Ai+ Nova': 'No',
    'Redmi A4': 'No',
    'Realme Narzo 80 Lite 4G': 'No',
    'Infinix Hot 60+': 'No',
    'Google Pixel 9': 'Yes',
    'Redmi 13': 'No',
    'Realme Narzo 80 Lite': 'No',
    'Vivo Y19e': 'No',
    'Motorola Edge 50': 'Yes',
    'Infinix Note 50x+': 'Yes',
    'Realme 14x': 'Yes',
    'Realme P3 Ultra': 'Yes',
    'Samsung Galaxy F36': 'Yes',
    'OnePlus Nord 5': 'Yes',
    'Infinix GT 30 Pro+': 'Yes',
    'iQOO Z10 Lite': 'Yes',
    'Apple iPhone 16 Pro': 'Yes',
    'Vivo T3': 'Yes',
    'Redmi Note 14 SE': 'No',
    'OnePlus 13R': 'Yes',
    'Samsung Galaxy S24+': 'Yes',
    'iQOO Z10': 'Yes',
    'itel P55': 'No',
    'Tecno Spark Go 1': 'No',
    'itel Zeno 10': 'No',
    'Moto G84': 'Yes',
    'Redmi 13C': 'No',
    'Lava Yuva Star 2': 'No',
    'itel A80': 'No',
    'Siavantage Pro 4': 'No',
    'Realme 14T': 'No',
    'Samsung Galaxy F15': 'Yes',
    'Samsung Galaxy F34': 'Yes',
    'Redmi A3': 'No',
    'Redmi 12': 'No',
    'Realme C55': 'No',
    'Vivo T2 Pro': 'Yes',
    'Samsung Galaxy A05s': 'No',
    'Samsung Galaxy Z Flip5': 'Yes',
    'OPPO Reno14': 'Yes',
    'Tecno Pova 7 Pro': 'Yes',
    'Infinix Smart 2': 'No',
    'Gionee Max': 'No',
    'Moto G73': 'Yes',
    'Samsung Galaxy Z Fold5': 'Yes',
    'Infinix Hot 12 Pro': 'No',
    'Moto G72': 'No',
    'Redmi Note 12': 'Yes',
    'Lava Blaze 2': 'Yes',
    'POCO F6': 'Yes',
    'Infinix Hot 10S': 'No',
    'Lava Z60': 'No',
    'itel A25 Pro': 'No',
    'Lava Z1s': 'No',
    'Samsung Galaxy On Nxt': 'No',
    'Infinix Smart 6': 'No',
    'POCO M5': 'No',
    'Tecno Camon 20': 'No',
    'XOLO ERA 1X': 'No',
    'Panasonic Eluga Ray 700': 'No',
    'Infinix Hot 10': 'No',
    'Lenovo Phab 2': 'No',
    'LG Q6+': 'No',
    'Samsung Galaxy S25': 'Yes',
    'Redmi A5': 'No',
    'Google Pixel 9a': 'Yes',
    'POCO X7 Pro': 'Yes',
    'iQOO Z10R': 'Yes',
    'iQOO Neo 10': 'Yes',
    'Realme 15 Pro': 'Yes',
    'Realme 15': 'Yes',
    'Realme Narzo 80x': 'Yes',
    'Snexian BOLD T240': 'No',
    'Realme C75': 'Yes',
    'Tecno POP 9': 'No',
    'Vivo X200 FE': 'Yes',
    'Realme 12+': 'Yes',
    'Samsung Galaxy M16': 'Yes',
    'Vivo T3 Pro': 'Yes',
    'Infinix Smart 10': 'No',
    'Motorola Razr 60': 'Yes',
    'Samsung Galaxy A16': 'Yes',
    'OnePlus Nord CE4': 'Yes',
    'Samsung M36': 'Yes',
    'Realme C73': 'Yes',
    'Samsung Galaxy A06': 'No',
    'Realme P3 Pro': 'Yes',
    'Realme P1 Speed': 'Yes',
    'Samsung Galaxy M35': 'Yes',
    'Redmi Note 14': 'Yes',
    'Vivo Y36': 'Yes',
    'Samsung Galaxy Z Fold6': 'Yes',
    'OPPO F29': 'Yes',
    'OPPO A3x': 'No',
    'Realme C63': 'Yes',
    'Vivo Y22': 'No',
    'Realme GT 6': 'Yes',
    'Realme P2 Pro': 'Yes',
    'Honor 200': 'Yes',
    'Tecno Pova Curve': 'Yes',
    'Vivo V50e': 'Yes',
    'Vivo T3 Lite': 'Yes',
    'OPPO A17k': 'No',
    'Redmi 14C': 'No',
    'Samsung Galaxy A36': 'Yes',
    'POCO M6 Plus': 'Yes',
    'Vivo T4 Ultra': 'Yes',
    'Lava Yuva Smart': 'No',
    'Realme 14 Pro': 'Yes',
    'Samsung Galaxy M06': 'No',
    'Redmi 13 Prime Edition': 'Yes',
    'Realme 13 Pro+': 'Yes',
    'Samsung Galaxy A15': 'No',
    'Realme Narzo 80 Pro': 'Yes',
    'Realme 14 Pro Lite': 'Yes',
    'Infinix Note 40': 'Yes',
    'Samsung Galaxy A56': 'Yes',
    'Lava Yuva 2': 'No',
    'Realme 14 Pro+': 'Yes',
    'Tecno Camon 30': 'Yes',
    'Motorola Edge 50 Ultra': 'Yes',
    'Realme Narzo N61': 'Yes',
    'iQOO Z9x': 'Yes',
    'Infinix Hot 50': 'Yes',
    'Xiaomi 14 CIVI': 'Yes',
    'OPPO K13 Turbo Pro': 'Yes',
    'Moto G54': 'Yes',
    'Samsung Galaxy S23 Ultra': 'Yes',
    'iQOO Z9s': 'Yes',
    'Vivo X200 Pro': 'Yes',
    'Samsung Galaxy S25 Ultra': 'Yes',
    'OPPO Reno14 Pro': 'Yes',
    'OnePlus 13s': 'Yes',
    'Vivo V60': 'Yes',
    'Samsung Galaxy M56': 'Yes',
    'Vivo T3 Ultra': 'Yes',
    'Samsung Galaxy F13': 'No',
    'Vivo Y400': 'Yes',
    'itel A50': 'No',
    'Nothing Phone 1': 'Yes',
    'Infinix Note 11': 'Yes',
    'Realme GT 7': 'Yes',
    'Samsung Galaxy A25': 'Yes',
    'Vivo V50': 'Yes',
    'Tecno Camon 20 Pro': 'Yes',
    'Vivo Y18t': 'No',
    'Lava Yuva Star': 'No',
    'OPPO F29 Pro': 'Yes',
    'Vivo Y400 Pro': 'Yes',
    'Redmi 13c': 'No',
    'Samsung Galaxy S23': 'Yes',
    'Samsung Galaxy Z Flip6': 'Yes',
    'Redmi Note 13 Pro': 'Yes',
    'Moto G32': 'No',
    'Google Pixel 7': 'Yes',
    'Vivo Y19': 'No',
    'itel A90': 'No',
    'Google Pixel 9 Pro Fold': 'Yes',
    'Vivo Y300 Plus': 'Yes',
    'Realme P1': 'Yes',
    'Redmi Note 14 Pro+': 'Yes',
    'Samsung Galaxy M13': 'No',
    'Samsung Galaxy A26': 'Yes',
    'POCO X6': 'Yes',
    'Redmi 9 Power': 'No',
    'Google Pixel 8 Pro': 'Yes',
    'Samsung Galaxy A23': 'Yes',
    'Google Pixel 9 Pro XL': 'Yes',
    'Tecno Spark 30C': 'No',
    'iQOO Z9s Pro': 'Yes',
    'POCO X6 Neo': 'Yes',
    'POCO X6 Pro': 'Yes',
    'Realme 13 Pro': 'Yes',
    'OnePlus 13': 'Yes',
    'Samsung Galaxy A14': 'No',
    'Redmi Note 8': 'No',
    'Vivo Y100A': 'Yes',
    'Samsung Galaxy M55s': 'Yes',
    'Xiaomi Mi 10T': 'Yes',
    'Vivo Y29': 'Yes',
    'Samsung Galaxy S23 FE': 'Yes',
    'Samsung Galaxy A04': 'No',
    'Realme 70 Turbo': 'Yes',
    'Vivo Y28s': 'No',
    'Redmi Note 14 Pro': 'Yes',
    'Vivo Y18i': 'No',
    'Moto G62': 'Yes',
    'Samsung Galaxy F23': 'Yes',
    'Samsung Galaxy S25 Plus': 'Yes',
    'Micromax IN Note 1': 'No',
    'OPPO A5 Pro': 'No',
    'itel A50C': 'No',
    'Samsung Galaxy M15': 'Yes',
    'itel Color Pro': 'No',
    'OPPO A3 Pro': 'Yes',
    'Realme Narzo N65': 'Yes',
    'Vivo V40 Pro': 'Yes',
    'OPPO F27': 'Yes',
}
a=list(is_5g.keys())
b=list(is_5g.values())
dic={
    'model_name':a,
    '5G_flag1':b
}
temp=pd.DataFrame(dic)
df=df.merge(temp,how='left',on='model_name')

# %%
df.drop(columns=['5G_flag'],inplace=True)

# %%
df.rename(columns={'5G_flag1':'5G_flag'},inplace=True)

# %%
df=df[['brand','model_name','color','price','5G_flag','avg_rating','reviews','battery','processor','RAM','ROM','display_size','display_type']]

# %%
df.to_csv('cleaned_smartphone_dataset.csv',index=False)

# %%
df.to_excel('cleaned_smartphone_dataset.xlsx',index=False)

# %%
df
# Out:
#         brand               model_name    color   price 5G_flag  avg_rating  \
# 0    MOTOROLA                 Moto G05    Green    6999      No         4.2
# 1        POCO                 POCO C71     Gold    6999      No         4.1
# 2        POCO                 POCO C71     Blue    6399      No         3.9
# 3     SAMSUNG       Samsung Galaxy F05     Blue    6499      No         4.2
# 4    MOTOROLA  Motorola Edge 60 Fusion  pantone   22999     Yes         4.5
# ..        ...                      ...      ...     ...     ...         ...
# 815   SAMSUNG       Samsung Galaxy A36    Black   30999     Yes         4.3
# 816    GOOGLE    Google Pixel 9 Pro XL    Other  119999     Yes         4.6
# 817     REDMI       Redmi Note 14 Pro+   Purple   26249     Yes         4.2
# 818    REALME                Realme P1    Green   13000     Yes         4.4
# 819      VIVO               Vivo Y100A     Gold   18999     Yes         4.3
#
# ...
